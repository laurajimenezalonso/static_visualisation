# %% [markdown]
# ## Visualización estática

# %% [markdown]
# Se entrega a mayores el Jupyter Notebook “limpieza-practica.ipynb”, se recomienda ejecutar esas líneas de código antes de resolver los ejercicios con el fin de preparar algunas de las variables que se usarán en las visualizaciones.
#
# He aprovechado este ejercicio para poner en práctica lo aprendido con visual code. He creado en mi máaquina en local una estructura de carpetas del proyecto:
#
# * data: para almacenar tanto fichero de entrada como de salida
# * docs: pdf con la práctica
# * mycode: cada uno de los diferentes ejercicios en fichero .py para poder trabajar independientement en cada uno de las diferentes partes del ejercicio
# * notebooks: donde se almacena este y otros notebooks. Los notebooks contienen la parte sumarizada de todos los diferentes ficheros con código
# * fichero de requirements
#
# Todo esto lo he ido subiendo a github para mantener un control de versiones. El repositorio es público.
# https://github.com/laurajimenezalonso/static_visualisation
#
# Empezamos!

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Leemos el fichero

# %%
data = pd.read_csv('../data/salaries.csv')

# %% [markdown]
# Para limpiar el campo 'country' miramos que valores unicos contiene.
# A continuacion iremos reemplazando cadenas de caracteres para alinear los paises

# %%
data['country'].unique()
# Out:
# array(['United States', 'United Kingdom', 'US', 'USA', 'Canada',
#        'United Kingdom ', 'usa', 'UK', 'Scotland ', 'U.S.',
#        'United States ', 'The Netherlands', 'Australia ', 'Spain', 'us',
#        'Usa', 'England', 'finland', 'United States of America', 'France',
#        'United states', 'Scotland', 'USA ', 'United states ', 'Germany',
#        'UK ', 'united states', 'Ireland', 'Australia', 'Uk',
#        'United States of America ', 'U.S. ', 'canada', 'Canada ', 'U.S>',
#        'ISA', 'Great Britain ', 'US ', 'United State', 'U.S.A', 'Denmark',
#        'U.S.A.', 'America', 'Netherlands', 'netherlands', 'England ',
#        'united states of america', 'Ireland ', 'Switzerland',
#        'Netherlands ', 'Bermuda', 'Us', 'The United States',
#        'United State of America', 'Germany ', 'Mexico ', 'United Stated',
#        'South Africa ', 'Belgium', 'Northern Ireland', 'u.s.',
#        'South Africa', 'UNITED STATES', 'united States', 'Sweden',
# ...

# %% [markdown]
# He ampliado el código que se nos dio para hacer más limpieza en los datos, ya que habían otros

# %%
data = data.assign(
    fixed_country=data.country.str.lower().str.strip()
)

#UK
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("king"), "united kingdom", data.fixed_country)
)
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.startswith("uk"), "united kingdom", data.fixed_country)
)
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.replace(" ", "").str.startswith("u.k"), "united kingdom", data.fixed_country)
)
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.replace(" ", "").str.startswith("u.k"), "united kingdom", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("kindom"), "united kingdom", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("england"), "united kingdom", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("engl"), "united kingdom", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("scot"), "united kingdom", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("britain"), "united kingdom", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("wales"), "united kingdom", data.fixed_country)
)


#US
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("state"), "united states", data.fixed_country)
)
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("america"), "united states", data.fixed_country)
)
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.startswith("us"), "united states", data.fixed_country)
)
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.replace(" ", "").str.startswith("u.s"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("isa"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("statws"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("status"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("sates"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("stattes"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("stares"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("status"), "united states", data.fixed_country)
)


data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("statss"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("i.s"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("is"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("the us"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("statues"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("sttes"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.startswith("us"), "united states", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("california"), "united states", data.fixed_country)
)
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("virginia"), "united states", data.fixed_country)
)
#Canada
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("canad"), "canada", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("canda"), "canada", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("cnada"), "canada", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.startswith("can"), "canada", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.startswith("csnada"), "canada", data.fixed_country)
)

#NL
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("nethe"), "netherland", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("nede"), "netherland", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.startswith("nl"), "netherland", data.fixed_country)
)
#HK
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("konh"), "hong kong", data.fixed_country)
)

#NZ
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("new z"), "new zealand", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("nz"), "new zealand", data.fixed_country)
)

#UAE

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("emirates"), "uae", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.startswith("ua"), "uae", data.fixed_country)
)

data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("u.a."), "uae", data.fixed_country)
)

#JAPAN
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("jap"), "japan", data.fixed_country)
)


#ITALY
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.startswith("ital"), "italy", data.fixed_country)
)

#AU
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.startswith("austra"), "australia", data.fixed_country)
)

#Spain
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("catalonia"), "spain", data.fixed_country)
)

#remote
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("remote"), "remote", data.fixed_country)
)

#denmark
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("danmark"), "denmark", data.fixed_country)
)

#romania
data = data.assign(
    fixed_country=np.where(data.fixed_country.str.contains("romania"), "denmark", data.fixed_country)
)

# %%
data.fixed_country.value_counts().reset_index().head(20)['count'].sum() / data.shape[0]
# Out:
# np.float64(0.9951709971530506)

# %%
fixed_country=data['fixed_country'].unique()
fixed_country
# Out:
# array(['united states', 'united kingdom', 'canada', 'netherland',
#        'australia', 'spain', 'finland', 'france', 'germany', 'ireland',
#        'denmark', 'switzerland', 'bermuda', 'mexico', 'south africa',
#        'belgium', 'northern ireland', 'sweden', 'hong kong', 'uae',
#        'sri lanka', 'contracts', 'greece', 'japan', 'austria', 'global',
#        'luxembourg', 'colombia', 'new zealand', 'latvia', 'puerto rico',
#        'rwanda', 'currently finance', 'serbia', 'russia', 'uxz', 'italy',
#        'hartford', 'china', 'cambodia', 'vietnam', 'remote', 'india',
#        'bangladesh', 'lithuania', 'eritrea', 'norway', 'cuba', 'slovenia',
#        "cote d'ivoire", 'somalia', 'malaysia', 'slovakia', 'sierra leone',
#        'singapore', 'international', 'the bahamas', 'costa rica',
#        'argentina', 'chile', 'qatar', 'hungary', 'nigeria', 'panamá',
#        'brazil', 'congo', 'uruguay', 'philippines', 'poland', 'malta',
# ...

# %% [markdown]
# Aun así, siguen habiendo pasies como *united y, y, currently finance, hartford, policy* o una bandera que no podemos limpiar de los datos.

# %% [markdown]
# ## Ejercicio 1 – Preparación de datos
#
# Queremos formatear los datos correctamente para prepararlos de cara a las visualizaciones solicitadas en los siguientes ejercicios. Para ello, se pide:
#
# * Leer los sets de datos proporcionados
# * Aplicar el tipo de cambio a las columnas de salario y bonus para que todo quede representado en USD
# * Eliminar datos con poca muestra que introducen ruido:
#     * Registros de las edades "under 18" y "65 or over".
#     * Registros con salarios anuales (sin bonus) por encima de los 200K dólares.
#     * Registros con géneros distintos a "Man" o "Woman".
#  * Imputar los valores faltantes (si los hay) de salario y bonus a 0.

# %% [markdown]
# Leemos el fichero exchange_rates.csv

# %%
fx= pd.read_csv('../data/exchange_rates.csv')
fx.head()
# Out:
#   currency  exchange_rate
# 0      AUD       0.671307
# 1      CAD       0.750496
# 2      CHF       1.058380
# 3      EUR       1.039290
# 4      GBP       1.191120

# %% [markdown]
# Para poder convertir todos los salarios. Hacemos un join donde nos traemos el tipo de cambio en funcion de la divisa.

# %%
data_usd=pd.merge(
    data,
    fx,
    on='currency',
    how='left'
)

# %%
data_usd
# Out:
#          age                       industry  \
# 0      25-34   Education (Higher Education)
# 1      25-34              Computing or Tech
# 2      25-34  Accounting, Banking & Finance
# 3      25-34                     Nonprofits
# 4      25-34  Accounting, Banking & Finance
# ...      ...                            ...
# 27744  25-34              Computing or Tech
# 27745  35-44       Property or Construction
# 27746  55-64                      Insurance
# 27747  55-64              Computing or Tech
# 27748  55-64                    Health care
#
#                                           title  annual_salary  bonus_salary  \
# 0            Research and Instruction Librarian        55000.0           0.0
# 1      Change & Internal Communications Manager        54600.0        4000.0
# 2                          Marketing Specialist        34000.0           NaN
# 3                               Program Manager        62000.0        3000.0
# ...

# %% [markdown]
# Creamos dos columnas nuevas, donde convertimos a USD el salario y el bonus anual.

# %%
data_usd['annual_salary_usd']=data_usd['annual_salary']*data_usd['exchange_rate'] 
data_usd['bonus_salary_usd']=data_usd['bonus_salary']*data_usd['exchange_rate'] 
data_usd['total_salary_usd']=(data_usd['bonus_salary']+data_usd['annual_salary'])*data_usd['exchange_rate']

# %% [markdown]
# Eliminamos los datos que nos piden en el enunciado para reducir el ruido.

# %%
#Eliminar
#   Registros de las edades "under 18" y "65 or over".
#   Registros con salarios anuales (sin bonus) por encima de los 200K dólares.
#   Registros con géneros distintos a "Man" o "Woman".
    
    
data_filtered = data_usd[
    (~data_usd['age'].isin(['under 18', '65 or over'])) &
    (data_usd['annual_salary_usd'] <= 200000) &
    (data_usd['gender'].isin(['Man', 'Woman']))
]

# %%
data_filtered.loc[:, 'annual_salary'] = data_filtered['annual_salary'].fillna(0)
data_filtered.loc[:, 'bonus_salary'] = data_filtered['bonus_salary'].fillna(0)
data_filtered.loc[:, 'annual_salary_usd'] = data_filtered['annual_salary_usd'].fillna(0)
data_filtered.loc[:, 'bonus_salary_usd'] = data_filtered['bonus_salary_usd'].fillna(0)
data_filtered.loc[:, 'total_salary_usd'] = data_filtered['total_salary_usd'].fillna(0)

# %% [markdown]
# Exporto el resultado filtrado a un csv. Durante la preceso de elaboración de los gráaficos, creé un fichero .py para cada uno de ellos. El primer paso era importa el fichero y los paquetes necesarios para cada uno de ellos. En el notebook, lo haré solamente una vez.

# %%
#Export data
data_filtered.to_csv('../data/cleanSalaries.csv', index=False)

#Import data
data = pd.read_csv('../data/cleanSalaries.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import ticker
from plotnine import *

# %% [markdown]
# ## Ejercicio 2 – Salario + bonus medio por país
# Queremos mostrar en un gráfico el salario + bonus medio que se tiene en cada país obtenido sobre los datos preparados en el ejercicio 1. Para ello:
#
# * Datos:
#     * Calcula el salario + bonus medio de cada uno de los países.
#     * Si son más de 8 países, quédate únicamente con el top 8 en términos de salario + bonus medio.
# * Eje X:
#     * Contenido: Cada uno de los países
#     * Nombre del eje: "País"
#     * Estilo del eje:
#         * Ticks y orden: los que muestre el gráfico por defecto en orden descendente en función del salario + bonus medio
# * Eje Y:
#     * Contenido: Salario + bonus medio de cada divisa
#     * Nombre del eje: "Salario medio"
#     * Estilo del eje:
#         * Ticks y orden: de 0 al máximo valor disponible cada 25.000.
#         * Etiquetas: números en formato $999K (p.e. $0K, $150K)
# * Estilo de las barras:
#     * Relleno en función de la divisa.
#     * Escala por defecto de plotnine.
# * Leyenda:
#     * Sin leyenda ya que es innecesaria
# * Título del gráfico:
#     * “Salario medio por divisa”

# %% [markdown]
# Preparamos los datos para este ejercicio 2, calculando la media de salario + bonus (en USD) para cada uno de los paises. Hemos visto anteriormente que el número de paises era mayor que 8, por lo  que nos quedamos con los primeros 8.

# %%
#Preparamos los datos
data_ej2=(
    data.groupby(['fixed_country','currency'])[['total_salary_usd']]
    .mean()
    .reset_index()
    .sort_values(by='total_salary_usd', ascending=False)
    .head(8)
)

# %% [markdown]
# Usando plotnine, podemos cambiar el relleno en función de la divisa fácilmente con aes fill.

# %%
#usando plotnine
(
    ggplot(data_ej2, aes(x='fixed_country', y='total_salary_usd', fill='currency')) +
    geom_bar(stat='identity') +
    ggtitle('Salario medio por divisa') +
    xlab('País') +
    ylab('Salario medio ($)') +
    scale_y_continuous(labels=lambda l: [f'${v//1000:,.0f}K' for v in l]) 
    
)

# %% [markdown]
# Para hacer lo mismo con matplotlib, tenemos que crear un diccionario, donde a cada una de las divisas se le asigne un color.
#
# He necesitado ayuda de ChatGPT a la hora de pintar un diccionario en una leyenda (función Patch).

# %%
# Crear un diccionario que asigne un color a cada divisa
currencies = data_ej2['currency'].unique()
len(currencies)
#vemos que hay 5 divisas. Podriamos crear una lista de colores mayor
colors = ['indianred','mediumseagreen','cornflowerblue','gold','violet']  # paleta de colores
color_map = {cur: colors[i % len(colors)] for i, cur in enumerate(currencies)}

# Asignar colores a cada fila según su divisa
bar_colors = data_ej2['currency'].map(color_map)

plt.bar(data_ej2.fixed_country, data_ej2.total_salary_usd, color=bar_colors)
plt.title('Salario medio por divisa')
plt.xlabel('Pais')
plt.xticks(fontsize=8)
plt.ylabel('Salario medio ($)')
plt.yticks(range(0, 200000, 25000), 
           labels=[f"${number//1000:,.0f}K" for number in range(0, 200000, 25000)])

# Leyenda directa desde el diccionario
from matplotlib.patches import Patch
legend_handles = [Patch(color=c, label=k) for k, c in color_map.items()]
plt.legend(handles=legend_handles, 
        title="Divisa",
        loc="upper center",       # punto de referencia en el centro superior
        bbox_to_anchor=(0.5, -0.1), 
        ncol=5,
        frameon=False)

plt.tight_layout()
plt.show()

# %% [markdown]
# Es mucho más sencillo usar plotnine que matplotlib, para objtener el mismo resultado.

# %% [markdown]
# ## Ejercicio 3 – Distribución salarial por edades
# Queremos mostrar un gráfico de densidad con la distribución de salarios (sin bonus) por
# edades obtenido sobre los datos preparados en el ejercicio 1. Para ello:
# * Datos:
#     * Añade una columna al set de datos con la mediana de salario de cada una de las edades.
# * Eje X:
#     * Contenido: Salario anual (sin bonus)
#     * Nombre del eje: "Salario anual (sin bonus)"
#     * Estilo del eje:
#         * Ticks y orden: de 0 a valor máximo cada 25.000.
#         * Etiquetas: números en formato $999K (p.e. $0K, $150K)
# * Eje Y:
#     * Contenido: Distribución/densidad del salario anual.
#     * Nombre del eje: "Distribución"
#     * Estilo del eje:
#         * Ticks y orden: sin ticks.
#         * Etiquetas: sin etiquetas.
# * Estilo de las densidades:
#     * Relleno en función de la edad y con una transparencia del 20%.
#     * Borde negro sin transparencia.
# * Multigráfico / Facetting:
#     * Obtener un gráfico por cada una de las edades: 18-24, 25-34, 35-44, 45-54, 55-64
#     * Organizados en vertical en una única columna.
# * Indicación de salario mediano:
#     * Incluir en cada gráfico de densidad una línea vertical que indique el salario mediano de la edad representada.
#     * Color de la línea: mismo color que la densidad de la edad sin relleno.
#     * Estilo de la línea: estilo líneas discontinuas (dashed).
# * Leyenda:
#     * Sin leyenda ya que es innecesaria
# * Título:
#     * Distribución de salario por edad

# %%
#Anadimos la columna median al dataset
data['median_salary_age'] = data.groupby('age')['annual_salary_usd'].transform('median')

#creamos el orden de las etiquetas
age_order = ['18-24', '25-34', '35-44', '45-54', '55-64']
colors = ['indianred','mediumseagreen','cornflowerblue','gold','violet']  # paleta de colores

# Rango máximo del eje X
max_salary = data['annual_salary_usd'].max()
max_x = int(np.ceil(max_salary / 25000.0)) * 25000



plt.figure(figsize=(8, 12))
plt.suptitle('Distribución de salario por edad')

# Recorremos todas las edades ahora
for i, element in enumerate(age_order):    

    # Subplot
    ax = plt.subplot2grid((len(age_order), 1), (i, 0))

    
    # Pintamos el gráfico
    ax.hist(
        data[data['age'] == element].loc[:, 'annual_salary_usd'].values,
        color= colors[i],
        bins=20,
        alpha=0.2,
        edgecolor="black")
    
    # Titulo de cada subplot
    ax.set_title(element)
    
    # Línea vertical en la mediana
    ax.axvline(data[data['age'] == element]['median_salary_age'].iloc[0], 
                color=colors[i], 
                linestyle="--", 
                linewidth=1.5)
    
    
    # Configuración del eje X
    xticks_vals = range(0, max_x + 1, 25000)
    xticks_labels = [f"${t//1000}K" for t in xticks_vals]
    ax.set_xticks(xticks_vals)
    ax.set_xticklabels(xticks_labels, rotation=0)
    ax.set_xlabel("Salario anual (sin bonus)")
    
    
    # Configuración del eje Y (sin ticks ni etiquetas)
    ax.set_yticks([])
    ax.set_yticklabels([])
    ax.set_ylabel("Distribución")
   

# Ajustamos los márgenes de cada gráfico después de añadir todos
plt.tight_layout()

plt.show()

# %% [markdown]
# Este gráfico muestra las para cada unas del grupo de edades, la distribución de sueldos, y cual es su medio.
# Se ha mantenido el eje de X para que se más fácil la comparación por grupos.
#
# Matplotlib no genera histograma realmente, para ello usaremos seaborn

# %%
import seaborn as sns

# Orden y colores
age_order = ['18-24', '25-34', '35-44', '45-54', '55-64']
colors = ['indianred','mediumseagreen','cornflowerblue','gold','violet']
age_colors = dict(zip(age_order, colors))

# Rango máximo del eje X
max_salary = data['annual_salary_usd'].max()
max_x = int(np.ceil(max_salary / 25000.0)) * 25000
xticks_vals = range(0, max_x + 1, 25000)
xticks_labels = [f'${t//1000}K' for t in xticks_vals]

# Usamos FacetGrid (una columna, faceteado por edad)
g = sns.FacetGrid(
    data, 
    row="age", 
    hue="age", 
    palette=age_colors, 
    row_order=age_order,
    sharex=True, 
    sharey=False, 
    height=2, aspect=4
)

# Densidad por cada edad
g.map(sns.kdeplot, "annual_salary_usd", fill=True, alpha=0.2)

# Líneas verticales de la mediana
for ax, age in zip(g.axes.flatten(), age_order):
    median_val = data.loc[data['age'] == age, 'median_salary_age'].iloc[0]
    ax.axvline(median_val, color=age_colors[age], linestyle="--", linewidth=1.5)

    # Configuración de ticks
    ax.set_xticks(xticks_vals)
    ax.set_xticklabels(xticks_labels, rotation=0)
    ax.set_xlabel("Salario anual (sin bonus)")
    ax.set_yticks([])
    ax.set_ylabel("Distribución")

# Título general
plt.subplots_adjust(top=0.92)
g.fig.suptitle("Distribución de salario por edad")

plt.show()

# %% [markdown]
# ## Ejercicio 4 – Brecha salarial
# Queremos mostrar un gráfico que represente la brecha salarial entre géneros por años de experiencia como boxplots sobre los datos preparados en el ejercicio 1. Para ello:
# * Datos:
#     * Utiliza el set de datos completo (sin filtros ni variables adicionales)
# * Eje X:
#     * Contenido: Salario anual (sin bonus)
#     * Nombre del eje: "Salario anual"
#     * Estilo del eje:
#         * Ticks y orden: de 0 a valor máximo cada 25.000.
#         * Etiquetas: números en formato $999K (p.e. $0K, $150K)
# * Eje Y:
#     * Contenido: Años de experiencia de campo
#     * Nombre del eje: "Experiencia (años)"
#     * Estilo del eje:
#         * Ticks y orden: '1 year or less', '2 - 4 years', '5-7 years', '8 - 10 years','11 - 20 years', '21 - 30 years', '31 - 40 years', '41 years or more'
#         * Etiquetas: ‘<1’,‘1-4’, ‘5-7’, ‘8-10’,’11-20’,’21-30’,’31-40’,‘>=41’
# * Estilo de los boxplot:
#     * Relleno en función del género.
#     * Color de los outliers también en función del género y con una transparencia del 20%.
# * Leyenda:
#     * Nombre de la variable de género en la leyenda: "Género"
#     * Nombre de los valores de la variable género en la leyenda: "Hombre" y "Mujer"
# * Título:
#     * Brecha salarial

# %%
# Orden de experiencia
exp_order = [
    '1 year or less', '2 - 4 years', '5-7 years', '8 - 10 years',
    '11 - 20 years', '21 - 30 years', '31 - 40 years', '41 years or more'
]
exp_labels = ['<1','1-4','5-7','8-10','11-20','21-30','31-40','>=41']

# Definir colores por género
gender_colors = {
    'Man': 'cornflowerblue',
    'Woman': 'indianred'
}


fig, axes = plt.subplots(2, 1, figsize=(6, 8), sharex=True, sharey=True)
fig.suptitle("Brecha salarial por experiencia", fontsize=16)

for ax, gender in zip(axes, ['Man', 'Woman']):
    subset = data[data['gender'] == gender]

    # Valores de salarios por experiencia (lista de arrays)
    values = [subset[subset['field_experience'] == exp]['annual_salary_usd'].dropna()
              for exp in exp_order]

    # Boxplot horizontal
    bp = ax.boxplot(
        values,
        vert=False,
        patch_artist=True,
        tick_labels=exp_labels,
        boxprops=dict(facecolor=gender_colors[gender], alpha=0.6),
        medianprops=dict(color="black"),
        capprops=dict(color="black"),
        flierprops=dict(marker="o", markersize=8, 
                        markerfacecolor=gender_colors[gender], 
                        alpha=0.2, markeredgecolor="black")
    )

    # Estética
    ax.set_title("Hombre" if gender == "Man" else "Mujer", fontsize=14)
    ax.set_xlabel("Salario anual", fontsize=12)
  

    # Eje X (ticks cada 25K, en formato $999K)
    max_salary = data['annual_salary_usd'].max()
    max_x = int(np.ceil(max_salary / 25000.0)) * 25000
    xticks_vals = range(0, max_x + 1, 25000)
    xticks_labels = [f"${t//1000}K" for t in xticks_vals]
    ax.set_xticks(xticks_vals)
    ax.set_xticklabels(xticks_labels, fontsize=12)
    ax.set_ylabel("Experiencia (años)", fontsize=12)


plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# Se puede hacer usando seaborn, todo en un mismo gráfico, que facilita la comparacion.

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(
    data=data,
    x='annual_salary_usd',
    y='field_experience',
    hue='gender',
    orient='h',
    palette={'Man': 'cornflowerblue', 'Woman': 'indianred'}
)

plt.yticks(ticks=range(len(exp_order)), labels=exp_labels)
plt.ylabel('Experiencia (años)')

max_salary = data['annual_salary_usd'].max()
max_x = int(np.ceil(max_salary / 25000.0)) * 25000
xticks_vals = range(0, max_x+1, 25000)
xticks_labels = [f'${t//1000}K' for t in xticks_vals]
plt.xticks(xticks_vals, xticks_labels)
plt.xlabel('Salario anual')

plt.title('Brecha salarial')

# Leyenda
handles, labels = plt.gca().get_legend_handles_labels()
label_map = {"man": "Hombre", "woman": "Mujer", "Man": "Hombre", "Woman": "Mujer"}
labels = [label_map.get(l.lower(), l) if hasattr(l, "lower") else l for l in labels]

plt.legend(handles, labels, title="Género")

plt.tight_layout()
plt.show()

# %% [markdown]
# Usando plotnine, se obtiene un formato muy parecido.

# %%
from plotnine import (
    ggplot, aes, geom_boxplot, coord_flip,
    scale_y_continuous, scale_x_discrete, scale_fill_manual,
    labs, theme, element_text, position_dodge
)
import numpy as np
import math

# ticks para el eje salario
max_salary = data['annual_salary_usd'].max()
max_x = int(math.ceil(max_salary / 25000.0)) * 25000
xticks = list(range(0, max_x + 1, 25000))

p = (
    ggplot(data, aes(x='field_experience', y='annual_salary_usd', fill='gender'))
    + geom_boxplot(position=position_dodge(width=0.8), width=0.6, outlier_alpha=0.2)
    + coord_flip()  # ahora queda horizontal: salario en X, experiencia en Y visualmente
    + scale_x_discrete(limits=exp_order, labels=exp_labels)   # orden y etiquetas de experiencia
    + scale_y_continuous(breaks=xticks, labels=[f"${t//1000}K" for t in xticks])  # ticks salario
    + scale_fill_manual(values={'Man': 'cornflowerblue', 'Woman': 'indianred'},
                        labels=['Hombre', 'Mujer'])
    + labs(x='Experiencia (años)', y='Salario anual', title='Brecha salarial', fill='Género')
    + theme(figure_size=(10, 6), axis_text_y=element_text(size=9))
)

p

# %% [markdown]
# ## Ejercicio 5 – Salario medio por edad y educación
# Queremos mostrar un gráfico que represente el salario medio por edad y educación como tiles sobre los datos preparados en el ejercicio 1.
#
# Para ello:
# * Datos:
#     * Calcular el salario medio (sin bonus) por edad y educación.
# * Eje X:
#     * Contenido: Educación
#     * Nombre del eje: "Educación"
#     * Estilo del eje:
#         * Ticks y orden: 'High School', 'Some college', 'College degree', 'Master's degree', 'Professional degree (MD, JD, etc.)', 'PhD'
#         * Etiquetas: 'High School', 'Some college', 'College degree', 'Master's degree', 'Professional degree', 'PhD'
#     * Estilo de los ticks: texto en ángulo de 90º y alineado a la derecha.
# * Eje Y:
#     * Contenido: Edad
#     * Nombre del eje: "Edad"
#     * Estilo del eje:
#         * Ticks y orden: '18-24', '25-34', '35-44', '45-54', '55-64'
#         * Etiquetas: '18-24', '25-34', '35-44', '45-54', '55-64'
# * Estilo de los tiles:
#     * Relleno en función del salario medio.
#     * Paleta de relleno "Greens" (más claro == valor más bajo, más oscuro == valor más alto).
# * Leyenda:
#     * Nombre de la variable de salario en la leyenda: "Salario medio (sin bonus)"
#     * Ticks de los valores de la variable de salario en la leyenda: de 40.000 a 120.000 dólares cada 40.000.
#     * Etiquetas de los valores de la variable salario en la leyenda: números en formato $999K (p.e. $0K, $150K)
# * Título:
#     * Salario medio por edad y educación

# %%
#Calcular el salario medio (sin bonus) por edad y educación.
data_ej5=(
    data.groupby(['age','education'])[['annual_salary_usd']]
    .mean()
    .reset_index()
)

education_order = [
    'High School',
    'Some college',
    'College degree',
    "Master's degree",
    'Professional degree (MD, JD, etc.)',
    'PhD'
]

education_labels = [ 
    'High School',
    'Some college',
    'College degree',
    "Maste's degree",
    'Professional degree',
    'PhD'
]

age_order = ['18-24', '25-34', '35-44', '45-54', '55-64']

#Pivotamos los datos para poder pasar la matriz al imshow
pivot_data_ej5 = data_ej5.pivot(
    index='age', 
    columns='education', 
    values='annual_salary_usd'
)


# Reordenamos los datos de la manera que queremos que salga en el orden que queremos
pivot_data_ej5 = pivot_data_ej5.reindex(
    index=age_order, 
    columns=education_order
)



#usando matplotlib
graph_5=plt.imshow(pivot_data_ej5, cmap='Greens')

plt.title('Salario medio por edad y educación')

# x axis
plt.xlabel('Educación')
plt.xticks(
    ticks=range(len(pivot_data_ej5.columns)), 
    labels=education_labels,
    rotation=90,
    ha='right'
)
# y axis
plt.ylabel('Edad')
plt.yticks(
    ticks=range(len(pivot_data_ej5.index)),
    labels=age_order
)



cbar=plt.colorbar(graph_5)
cbar.set_label("Salario medio (sin bonus)")

ticks = list(range(40000, 120001, 40000))

cbar.set_ticks(ticks)
cbar.set_ticklabels([f"${t//1000}K" for t in ticks])

plt.show()
